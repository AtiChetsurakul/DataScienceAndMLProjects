# %%
import numpy as np
import mne

# %% [markdown]
# ### try to run using `mne.io.read_raw_edf`

# %%
# sample_data_folder = mne.datasets.sample.data_path()
# sample_data_raw_file = (sample_data_folder / 'MEG' / 'sample' /
#                         'sample_audvis_filt-0-40_raw.fif')
# raw = mne.io.read_raw_fif(sample_data_raw_file)

# %%
raw = mne.io.read_raw_edf('/root/projects/ProjectAug22/CP/EEG_motorIg/data_keep/physionet.org/files/eegmmidb/1.0.0/S001/S001R01.edf')
# Out:
# Extracting EDF parameters from /root/projects/ProjectAug22/CP/EEG_motorIg/data_keep/physionet.org/files/eegmmidb/1.0.0/S001/S001R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
print(raw)
print(raw.info)
# Out:
# <RawEDF | S001R01.edf, 64 x 9760 (61.0 s), ~64 kB, data not loaded>
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 80.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
# >

# %%
raw.plot_psd(fmax=50)
raw.plot(duration=10, n_channels=64)
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 1.600 (s)
# /tmp/ipykernel_2499/735232987.py:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.plot_psd(fmax=50)
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
print(raw.ch_names)
# Out:
# ['Fc5.', 'Fc3.', 'Fc1.', 'Fcz.', 'Fc2.', 'Fc4.', 'Fc6.', 'C5..', 'C3..', 'C1..', 'Cz..', 'C2..', 'C4..', 'C6..', 'Cp5.', 'Cp3.', 'Cp1.', 'Cpz.', 'Cp2.', 'Cp4.', 'Cp6.', 'Fp1.', 'Fpz.', 'Fp2.', 'Af7.', 'Af3.', 'Afz.', 'Af4.', 'Af8.', 'F7..', 'F5..', 'F3..', 'F1..', 'Fz..', 'F2..', 'F4..', 'F6..', 'F8..', 'Ft7.', 'Ft8.', 'T7..', 'T8..', 'T9..', 'T10.', 'Tp7.', 'Tp8.', 'P7..', 'P5..', 'P3..', 'P1..', 'Pz..', 'P2..', 'P4..', 'P6..', 'P8..', 'Po7.', 'Po3.', 'Poz.', 'Po4.', 'Po8.', 'O1..', 'Oz..', 'O2..', 'Iz..']

# %%
# ica = mne.preprocessing.ICA(n_components=64, random_state=97, max_iter=800)
# ica.fit(raw)
# ica.exclude = [1, 2]  # details on how we picked these are omitted here
# ica.plot_properties(raw, picks=ica.exclude)
