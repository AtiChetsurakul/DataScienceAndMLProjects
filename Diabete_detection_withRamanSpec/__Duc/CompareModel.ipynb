# %% [markdown]
# ![image.png](attachment:e53ed1fe-6390-4d21-bae0-4b1b9f95f3fe.png)

# %% [markdown]
# * In this case, this model works well in thumb nail. It also achieves somehow good in inner arm, but it tends to go overfitting. On the other hand, in median cubital vein and ear lobe, it's not good because the loss of validation set keeps rising.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:1c9ae4e6-6aa8-4333-9ca2-2886c4f061ed.png)

# %% [markdown]
# * In this case, it achieves somehow good in ear lobe area, but it also can go overfitting. By the way, in the other three locations, this model doesn't perform well due to rising in the loss of validation.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:32e9fe87-2b51-4acc-afcc-e60bb13efd16.png)

# %% [markdown]
# * In this case, this model performs somehow good in thumb nail and median cubital vein with high accuracy, but the loss of validation tends to rise up. On the other hand, it doesn't work well in ear lobe and inner arm.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:7dfdb6d4-e81b-4a07-8167-a9f19c2dc0cc.png)

# %% [markdown]
# * Perfect fitting in thumb nail.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:f617533f-3786-4fc3-9d9b-5e275ceecfa6.png)

# %% [markdown]
# # Overall, when look at those plots, this model seems to fit better in thumbnail and it somehow fits with inner arm. On the other hand, it performs bad in the other two locations.

# %%
earlobe = (25+75+0+25+25)/5
print("earlobe: ", earlobe)

inner_arm = (75+50+50+25+75)/5

print("inner_arm: ",inner_arm)

thumb_nail = (75+25+75+100+75)/5 

print("thumb_nail: ",thumb_nail)

median_cubital_vein = (50 +25+75+0+50)/5
print("median_cubital_vein: ",median_cubital_vein)
# Out:
# earlobe:  30.0
# inner_arm:  55.0
# thumb_nail:  70.0
# median_cubital_vein:  40.0
