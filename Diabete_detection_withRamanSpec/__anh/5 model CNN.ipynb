# %% [markdown]
# ### 25811243

# %% [markdown]
# ![image.png](attachment:fefcded5-180d-42e4-a268-12e5d878458b.png)

# %% [markdown]
# With this seed we see that ear lobe, inner arm and thumb nail are not good because the val loss increases gradually and is much larger than train. Median cubital vein is quite good compared to this seeb.

# %% [markdown]
# #### 34806794

# %% [markdown]
# ![image.png](attachment:6d664bab-28fc-4e3e-9b44-97b1f0eb3e06.png)

# %% [markdown]
# With this seed, we see that the model is not good because the val loss is too high in four location.

# %% [markdown]
# ### 2022

# %% [markdown]
# ![image.png](attachment:d993f548-6fc6-4dd4-9b42-2eafbe5fce67.png)

# %% [markdown]
# Looking at this seed we see that the thumb nail and median cubital vein are good compared to this model, the ear lobe is normal and the inner arm is quite bad.

# %% [markdown]
# ### 1910

# %% [markdown]
# ![image.png](attachment:b1b9e84a-6738-465d-9ab5-a6abdf2746dc.png)

# %% [markdown]
# Looking at this seed, we see a very good thumb nail model with acc 100.0. median cubital vein, ear lobe, inner arm are pretty bad.

# %% [markdown]
# ### 222

# %% [markdown]
# ![image.png](attachment:1f59f329-3212-4157-badf-68d69663a7ec.png)

# %% [markdown]
# With this seed, we see that the model is not good because the val loss is too high in four location.

# %%
earlobe = (25+75+50+0+50)/5
print("earlobe: ", earlobe)

inner_arm = (50 +50 +50 +25 +75)/5

print("inner_arm: ",inner_arm)

thumb_nail = 75+50+75+100+75 

print("thumb_nail: ",thumb_nail)

median_cubital_vein = 50 + 25 +75 +0 +50
print("median_cubital_vein: ",median_cubital_vein)
# Out:
# earlobe:  200
# inner_arm:  250
# thumb_nail:  375
# median_cubital_vein:  200
