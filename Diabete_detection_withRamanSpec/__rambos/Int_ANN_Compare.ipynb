# %% [markdown]
# # Inter_ANN Comparation

# %% [markdown]
# #### Raman spectroscopy

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# - The model accuracy mostly perform well in Thumb nail.

# %% [markdown]
# ## Caculate the accuracy

# %%
earlobe = (25+75+25+25+25)/5
print("earlobe: ", earlobe)

inner_arm = (25 +25 +25 +0 +25)/5

print("inner_arm: ",inner_arm)

thumb_nail = (75+25+25+100+75)/5 

print("thumb_nail: ",thumb_nail)

median_cubital_vein = (25 + 25 +75 +0 +25)/5
print("median_cubital_vein: ",median_cubital_vein)
# Out:
# earlobe:  35.0
# inner_arm:  20.0
# thumb_nail:  60.0
# median_cubital_vein:  30.0
